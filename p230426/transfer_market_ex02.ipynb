# %%
# 1-100등까지 추출
from urllib import request
import requests
from bs4 import BeautifulSoup
import pandas

# %%
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'}

player_list = []

for idx in range(1, 5):
    url = f'https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?ajax=yw1&page={idx}'
    html = requests.get(url, headers=headers)
    
    soup = BeautifulSoup(html.text, 'html.parser')

    player_info = soup.find_all('tr',class_=['odd', 'even'])
    
    for player in player_info:
        info = player.find_all('td')
        
        number = info[0].text
        name = info[3].text
        position = info[4].text
        age = info[5].text
        nation = info[6].img['title']
        team = info[7].img['title']
        value = info[8].text.strip()
        
        player_list.append([number, name, position, age, nation, team, value])

print(player_list)
# Out:
# [['1', 'Kylian Mbappé', 'Centre-Forward', '24', 'France', 'Paris Saint-Germain', '€180.00m'], ['2', 'Erling Haaland', 'Centre-Forward', '22', 'Norway', 'Manchester City', '€170.00m'], ['3', 'Jude Bellingham', 'Central Midfield', '19', 'England', 'Borussia Dortmund', '€120.00m'], ['4', 'Vinicius Junior', 'Left Winger', '22', 'Brazil', 'Real Madrid', '€120.00m'], ['5', 'Jamal Musiala', 'Attacking Midfield', '20', 'Germany', 'Bayern Munich', '€110.00m'], ['6', 'Bukayo Saka', 'Right Winger', '21', 'England', 'Arsenal FC', '€110.00m'], ['7', 'Phil Foden', 'Left Winger', '22', 'England', 'Manchester City', '€110.00m'], ['8', 'Pedri', 'Central Midfield', '20', 'Spain', 'FC Barcelona', '€100.00m'], ['9', 'Victor Osimhen', 'Centre-Forward', '24', 'Nigeria', 'SSC Napoli', '€100.00m'], ['10', 'Federico Valverde', 'Central Midfield', '24', 'Uruguay', 'Real Madrid', '€100.00m'], ['11', 'Gavi', 'Central Midfield', '18', 'Spain', 'FC Barcelona', '€90.00m'], ['12', 'Aurélien Tchouaméni', 'Defensive Midfield', '23', 'France', 'Real Madrid', '€90.00m'], ['13', 'Harry Kane', 'Centre-Forward', '29', 'England', 'Tottenham Hotspur', '€90.00m'], ['14', 'Enzo Fernández', 'Defensive Midfield', '22', 'Argentina', 'Chelsea FC', '€85.00m'], ['15', 'Florian Wirtz', 'Attacking Midfield', '19', 'Germany', 'Bayer 04 Leverkusen', '€85.00m'], ['16', 'Khvicha Kvaratskhelia', 'Left Winger', '22', 'Georgia', 'SSC Napoli', '€85.00m'], ['17', 'Rodrygo', 'Right Winger', '22', 'Brazil', 'Real Madrid', '€80.00m'], ['18', 'Lautaro Martínez', 'Centre-Forward', '25', 'Argentina', 'Inter Milan', '€80.00m'], ['19', 'Declan Rice', 'Defensive Midfield', '24', 'England', 'West Ham United', '€80.00m'], ['20', 'Rodri', 'Defensive Midfield', '26', 'Spain', 'Manchester City', '€80.00m'], ['21', 'Rafael Leão', 'Left Winger', '23', 'Portugal', 'AC Milan', '€80.00m'], ['22', 'Christopher Nkunku', 'Second Striker', '25', 'France', 'RB Leipzig', '€80.00m'], ['23', 'Martin Ødegaard', 'Attacking Midfield', '24', 'Norway', 'Arsenal FC', '€80.00m'], ['24', 'Marcus Rashford', 'Left Winger', '25', 'England', 'Manchester United', '€80.00m'], ['25', 'Bernardo Silva', 'Attacking Midfield', '28', 'Portugal', 'Manchester City', '€80.00m'], ['26', 'Joshua Kimmich', 'Defensive Midfield', '28', 'Germany', 'Bayern Munich', '€80.00m'], ['27', 'Kevin De Bruyne', 'Attacking Midfield', '31', 'Belgium', 'Manchester City', '€80.00m'], ['28', 'Luis Díaz', 'Left Winger', '26', 'Colombia', 'Liverpool FC', '€75.00m'], ['29', 'Josko Gvardiol', 'Centre-Back', '21', 'Croatia', 'RB Leipzig', '€75.00m'], ['30', 'Gabriel Jesus', 'Centre-Forward', '26', 'Brazil', 'Arsenal FC', '€75.00m'], ['31', 'Dusan Vlahovic', 'Centre-Forward', '23', 'Serbia', 'Juventus FC', '€75.00m'], ['32', 'Matthijs de Ligt', 'Centre-Back', '23', 'Netherlands', 'Bayern Munich', '€75.00m'], ['33', 'Rúben Dias', 'Centre-Back', '25', 'Portugal', 'Manchester City', '€75.00m'], ['34', 'Bruno Fernandes', 'Attacking Midfield', '28', 'Portugal', 'Manchester United', '€75.00m'], ['35', 'Gabriel Martinelli', 'Left Winger', '21', 'Brazil', 'Arsenal FC', '€70.00m'], ['36', 'Antony', 'Right Winger', '23', 'Brazil', 'Manchester United', '€70.00m'], ['37', 'Darwin Núñez', 'Centre-Forward', '23', 'Uruguay', 'Liverpool FC', '€70.00m'], ['38', 'Ronald Araújo', 'Centre-Back', '24', 'Uruguay', 'FC Barcelona', '€70.00m'], ['39', 'Reece James', 'Right-Back', '23', 'England', 'Chelsea FC', '€70.00m'], ['40', 'Alphonso Davies', 'Left-Back', '22', 'Canada', 'Bayern Munich', '€70.00m'], ['41', 'Éder Militão', 'Centre-Back', '25', 'Brazil', 'Real Madrid', '€70.00m'], ['42', 'Achraf Hakimi', 'Right-Back', '24', 'Morocco', 'Paris Saint-Germain', '€70.00m'], ['43', 'Nicolò Barella', 'Central Midfield', '26', 'Italy', 'Inter Milan', '€70.00m'], ['44', 'Jack Grealish', 'Left Winger', '27', 'England', 'Manchester City', '€70.00m'], ['45', 'Leroy Sané', 'Right Winger', '27', 'Germany', 'Bayern Munich', '€70.00m'], ['46', 'Marquinhos', 'Centre-Back', '28', 'Brazil', 'Paris Sai ...

# %%
df = pandas.DataFrame(player_list, columns=['number', 'name', 'position', 'age', 'nation', 'team', 'value'])
df
# Out:
#    number                  name            position age   nation
# 0       1         Kylian Mbappé      Centre-Forward  24   France  \
# 1       2        Erling Haaland      Centre-Forward  22   Norway
# 2       3       Jude Bellingham    Central Midfield  19  England
# 3       4       Vinicius Junior         Left Winger  22   Brazil
# 4       5         Jamal Musiala  Attacking Midfield  20  Germany
# ..    ...                   ...                 ...  ..      ...
# 95     96  Gianluigi Donnarumma          Goalkeeper  24    Italy
# 96     97       Lucas Hernández         Centre-Back  27   France
# 97     98            Ivan Toney      Centre-Forward  27  England
# 98     99        Marco Verratti    Central Midfield  30    Italy
# 99    100           David Alaba         Centre-Back  30  Austria
#
#                    team     value
# 0   Paris Saint-Germain  €180.00m
# 1       Manchester City  €170.00m
# 2     Borussia Dortmund  €120.00m
# 3           Real Madrid  €120.00m
# 4         Bayern Munich  €110.00m
# ..                  ...       ...
# 95  Paris Saint-Germain   €50.00m
# 96        Bayern Munich   €50.00m
# 97         Brentford FC   €50.00m
# 98  Paris Saint-Germain   €50.00m
# 99          Real Madrid   €50.00m
#
# [100 rows x 7 columns]

# %%
df.to_csv('market100.csv', index=False)
print('==저장 완료==')
# Out:
# ==저장 완료==
